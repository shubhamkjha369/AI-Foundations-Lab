# %%
import torch

# %% [markdown]
# # 1. Inplace Operations

# %%
m = torch.rand(2, 3)
n = torch.rand(2, 3)

print(m)
print(n)
# Out:
# tensor([[0.4243, 0.4693, 0.4990],
#         [0.2089, 0.8707, 0.7142]])
# tensor([[0.1784, 0.3630, 0.8637],
#         [0.4152, 0.2986, 0.3441]])

# %%
m.add_(n)
# Out:
# tensor([[0.6027, 0.8323, 1.3627],
#         [0.6242, 1.1693, 1.0583]])

# %%
m
# Out:
# tensor([[0.6027, 0.8323, 1.3627],
#         [0.6242, 1.1693, 1.0583]])

# %%
m.relu_()
# Out:
# tensor([[0.6027, 0.8323, 1.3627],
#         [0.6242, 1.1693, 1.0583]])

# %%
m
# Out:
# tensor([[0.6027, 0.8323, 1.3627],
#         [0.6242, 1.1693, 1.0583]])

# %% [markdown]
# # 2. Copying a Tensor

# %%
a = torch.rand(2, 3)
a
# Out:
# tensor([[0.2576, 0.6043, 0.5664],
#         [0.9164, 0.2316, 0.2038]])

# %%
b = a

# %%
b
# Out:
# tensor([[0.2576, 0.6043, 0.5664],
#         [0.9164, 0.2316, 0.2038]])

# %%
# PROBLEM -- not desirable

a[0][0] = 0
a
# Out:
# tensor([[0.0000, 0.6043, 0.5664],
#         [0.9164, 0.2316, 0.2038]])

# %%
b
# Out:
# tensor([[0.0000, 0.6043, 0.5664],
#         [0.9164, 0.2316, 0.2038]])

# %%
id(a)
# Out:
# 3051731227008

# %%
id(b)
# Out:
# 3051731227008

# %%
## SOLUTION

b = a.clone()

# %%
a
# Out:
# tensor([[0.0000, 0.6043, 0.5664],
#         [0.9164, 0.2316, 0.2038]])

# %%
b
# Out:
# tensor([[0.0000, 0.6043, 0.5664],
#         [0.9164, 0.2316, 0.2038]])

# %%
a[1][1] = -43
a
# Out:
# tensor([[  0.0000,   0.6043,   0.5664],
#         [  0.9164, -43.0000,   0.2038]])

# %%
b
# Out:
# tensor([[0.0000, 0.6043, 0.5664],
#         [0.9164, 0.2316, 0.2038]])

# %%
id(a)
# Out:
# 3051731227008

# %%
id(b)
# Out:
# 3051731232048

# %%
a.relu_()
# Out:
# tensor([[0.0000, 0.6043, 0.5664],
#         [0.9164, 0.0000, 0.2038]])

# %%
a
# Out:
# tensor([[0.0000, 0.6043, 0.5664],
#         [0.9164, 0.0000, 0.2038]])

# %%
b
# Out:
# tensor([[0.0000, 0.6043, 0.5664],
#         [0.9164, 0.2316, 0.2038]])
