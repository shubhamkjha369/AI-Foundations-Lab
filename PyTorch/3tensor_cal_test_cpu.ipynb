# %%
import torch
import time

# %%
size = 10000

a = torch.randn(size, size)
b = torch.randn(size, size)

start = time.time()
result = torch.matmul(a, b)
end = time.time() - start

print(f"Time taken: {end:.4f} seconds")
# Out:
# Time taken: 13.9620 seconds
